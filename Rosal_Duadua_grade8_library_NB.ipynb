# %% [markdown]
# <a href="https://colab.research.google.com/github/GillianODuadua/Rosal-Duadua-grade8-library-Repo/blob/main/Rosal_Duadua_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

url = "https://raw.githubusercontent.com/GillianODuadua/Rosal-Duadua-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(url)
books = response.json()

print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db

cred = credentials.Certificate("/content/firebase_key.json")

firebase_admin.initialize_app(cred, { "databaseURL": "https://rosal-duadua-grade8-libr-65214-default-rtdb.asia-southeast1.firebasedatabase.app/"})
print("Firebase connected successfully!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2009586677.py in <cell line: 0>()
#       4 cred = credentials.Certificate("/content/firebase_key.json")
#       5
# ----> 6 firebase_admin.initialize_app(cred, { "databaseURL": "https://rosal-duadua-grade8-libr-65214-default-rtdb.asia-southeast1.firebasedatabase.app/"})
#       7 print("Firebase connected successfully!")
#
# /usr/local/lib/python3.12/dist-packages/firebase_admin/__init__.py in initialize_app(credential, options, name)
#      72
#      73     if name == _DEFAULT_APP_NAME:
# ---> 74         raise ValueError((
#      75             'The default Firebase app already exists. This means you called '
#      76             'initialize_app() more than once without providing an app name as '
#
# ...

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# None

# %%
import json
with open("/content/books.json") as file:
  data = json.load(file)
print("JSON file loaded")
ref = db.reference("books")
for book in data["books"]:
  ref.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
import requests
import json
"""
The 'students' variable is already loaded from the URL in a previous cell.
Therefore, we can directly use the 'students' variable.
"""
data = books
print("JSON file loaded")
ref = db.reference("books")

for book in data["books"]:
  ref.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for books_id, info in books_data.items():
    print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for books_id, info in books_data.items():
  print(info["title"],"-", info["details"]["available"])
# Out:
# Introduction to Python - 3
# Data Structures Basics - 2
# Web Development Essentials - 6

# %%
copies_list = []

for books_id, info in books_data.items():
  copies_list.append(info["details"]["copies"])

total_books = sum(copies_list)
print("Total number of books:", total_books)
# Out:
# Total number of books: 15
